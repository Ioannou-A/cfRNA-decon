# %% [markdown]
# This script scans each directory for nuSVR_Rerun_*.txt files generated during the nuSVR hyperparameter search. For every sample, it reads the RMSE-PredictedCounts metric, identifies the C and nu combination that yields the lowest RMSE, and copies that file as the final output (nuSVR_CountsRMSE_Random_<sample>.txt). This replicates the selection logic of the slower original script but for the problematic samples.

# %%
import os
import glob
import pandas as pd
import shutil

# directory with rerun files
dir_pattern = "Decon-COO-Results_Loy_Inflammatory-Syndromes_nuSVR/"
directories = sorted(glob.glob(dir_pattern))

print(f"Found {len(directories)} directories.")

for input_dir in directories:
    print(f"\nProcessing directory: {input_dir}")

    pattern = os.path.join(input_dir, "nuSVR_Rerun_*.txt")
    files = glob.glob(pattern)

    if not files:
        print("  No rerun files found — skipping.")
        continue

    samples = {}

    for f in files:
        name = os.path.basename(f)
        parts = name.replace(".txt", "").split("_")

        # sample ID = everything between 3rd token and C/nu
        sample_id = "_".join(parts[3:-2])

        # C and nu always at the end
        C_val = parts[-2].replace("C", "")
        nu_val = parts[-1].replace("nu", "")

        df = pd.read_csv(f, sep="\t")
        rmse = float(df["RMSE-PredictedCounts"].iloc[0])

        # keep best RMSE per sample
        if sample_id not in samples or rmse < samples[sample_id]["rmse"]:
            samples[sample_id] = {
                "rmse": rmse,
                "file": f,
                "C": C_val,
                "nu": nu_val
            }

    # copy and rename winning files
    for sample_id, info in samples.items():
        best_file = info["file"]
        rmse = info["rmse"]
        C_val = info["C"]
        nu_val = info["nu"]

        # output format you requested
        new_name = f"nuSVR_CountsRMSE_Random_{sample_id}.txt"
        new_path = os.path.join(input_dir, new_name)

        shutil.copy(best_file, new_path)

        print(f"  Sample: {sample_id}")
        print(f"    → Best RMSE: {rmse:.6f}")
        print(f"    → Best C:  {C_val}")
        print(f"    → Best nu: {nu_val}")
        print(f"    → Saved: {new_path}")
# Out:
# Found 1 directories.
#
# Processing directory: Decon-COO-Results_Loy_Inflammatory-Syndromes_nuSVR/
#   Sample: kd_105
#     → Best RMSE: 1.003796
#     → Best C:  0.5
#     → Best nu: 0.05
#     → Saved: Decon-COO-Results_Loy_Inflammatory-Syndromes_nuSVR/nuSVR_CountsRMSE_Random_kd_105.txt
#   Sample: cu_cfrna_252
#     → Best RMSE: 0.771934
#     → Best C:  1
#     → Best nu: 0.1
#     → Saved: Decon-COO-Results_Loy_Inflammatory-Syndromes_nuSVR/nuSVR_CountsRMSE_Random_cu_cfrna_252.txt
#   Sample: cu_cfrna_287
#     → Best RMSE: 0.890132
#     → Best C:  0.1
#     → Best nu: 0.1
#     → Saved: Decon-COO-Results_Loy_Inflammatory-Syndromes_nuSVR/nuSVR_CountsRMSE_Random_cu_cfrna_287.txt
#   Sample: kd_279.trimmed
#     → Best RMSE: 0.894493
#     → Best C:  0.1
#     → Best nu: 0.15
#     → Saved: Decon-COO-Results_Loy_Inflammatory-Syndromes_nuSVR/nuSVR_CountsRMSE_Random_kd_279.trimmed.txt
#   Sample: cu_cfrna_278
#     → Best RMSE: 0.820286
#     → Best C:  0.1
#     → Best nu: 0.25
#     → Saved: Decon-COO-Results_Loy_Inflammatory-Syndromes_nuSVR/nuSVR_CountsRMSE_Random_cu_cfrna_278.txt
#   Sample: kd_257.trimmed
#     → Best RMSE: 0.921406
#     → Best C:  0.1
#     → Best nu: 0.05
#     → Saved: Decon-COO-Results_Loy_Inflammatory-Syndromes_nuSVR/nuSVR_CountsRMSE_Random_kd_257.trimmed.txt
#   Sample: kd_241.trimmed
#     → Best RMSE: 1.066455
#     → Best C:  0.75
#     → Best nu: 0.05
#     → Saved: Decon-COO-Results_Loy_Inflammatory-Syndromes_nuSVR/nuSVR_CountsRMSE_Random_kd_241.trimmed.txt
#   Sample: kd_9
#     → Best RMSE: 0.869091
#     → Best C:  0.1
#     → Best nu: 0.15
#     → Saved: Decon-COO-Results_Loy_Inflammatory-Syndromes_nuSVR/nuSVR_CountsRMSE_Random_kd_9.txt
#   Sample: kd_312.trimmed
#     → Best RMSE: 0.902737
#     → Best C:  0.5
#     → Best nu: 0.05
#     → Saved: Decon-COO-Results_Loy_Inflammatory-Syndromes_nuSVR/nuSVR_CountsRMSE_Random_kd_312.trimmed.txt
#   Sample: cu_cfrna_196
#     → Best RMSE: 1.005254
#     → Best C:  0.1
#     → Best nu: 0.05
#     → Saved: Decon-COO-Results_Loy_Inflammatory-Syndromes_nuSVR/nuSVR_CountsRMSE_Random_cu_cfrna_196.txt
