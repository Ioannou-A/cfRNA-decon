# %% [markdown]
# This script scans each directory for nuSVR_Rerun_*.txt files generated during the nuSVR hyperparameter search. For every sample, it reads the RMSE-PredictedCounts metric, identifies the C and nu combination that yields the lowest RMSE, and copies that file as the final output (nuSVR_CountsRMSE_Random_<sample>.txt). This replicates the selection logic of the slower original script but for the problematic samples.

# %%
import os
import glob
import pandas as pd
import shutil

# find all directories matching the pattern
dir_pattern = "CIBERSORTx-Matrix_TSP-*_10/"
directories = sorted(glob.glob(dir_pattern))

print(f"Found {len(directories)} directories.")

for input_dir in directories:
    print(f"\nProcessing directory: {input_dir}")

    pattern = os.path.join(input_dir, "nuSVR_Rerun_*.txt")
    files = glob.glob(pattern)

    if not files:
        print("  No rerun files found — skipping.")
        continue

    samples = {}

    for f in files:
        name = os.path.basename(f)
        parts = name.replace(".txt", "").split("_")

        # sample ID = everything between 3rd token and C/nu
        sample_id = "_".join(parts[3:-2])

        # C and nu always at the end
        C_val = parts[-2].replace("C", "")
        nu_val = parts[-1].replace("nu", "")

        df = pd.read_csv(f, sep="\t")
        rmse = float(df["RMSE-PredictedCounts"].iloc[0])

        # keep best RMSE per sample
        if sample_id not in samples or rmse < samples[sample_id]["rmse"]:
            samples[sample_id] = {
                "rmse": rmse,
                "file": f,
                "C": C_val,
                "nu": nu_val
            }

    # copy and rename winning files
    for sample_id, info in samples.items():
        best_file = info["file"]
        rmse = info["rmse"]
        C_val = info["C"]
        nu_val = info["nu"]

        # output format you requested
        new_name = f"nuSVR_CountsRMSE_Random_{sample_id}.txt"
        new_path = os.path.join(input_dir, new_name)

        shutil.copy(best_file, new_path)

        print(f"  Sample: {sample_id}")
        print(f"    → Best RMSE: {rmse:.6f}")
        print(f"    → Best C:  {C_val}")
        print(f"    → Best nu: {nu_val}")
        print(f"    → Saved: {new_path}")
# Out:
# Found 9 directories.
#
# Processing directory: CIBERSORTx-Matrix_TSP-BDa_Inner_1000_3000_10/
#   No rerun files found — skipping.
#
# Processing directory: CIBERSORTx-Matrix_TSP-BDa_Inner_3000_5000_10/
#   Sample: random_rep1_seed13_10_200
#     → Best RMSE: 0.432635
#     → Best C:  0.5
#     → Best nu: 0.75
#     → Saved: CIBERSORTx-Matrix_TSP-BDa_Inner_3000_5000_10/nuSVR_CountsRMSE_Random_random_rep1_seed13_10_200.txt
#   Sample: random_rep3_seed9_20_400
#     → Best RMSE: 0.145596
#     → Best C:  0.5
#     → Best nu: 0.15
#     → Saved: CIBERSORTx-Matrix_TSP-BDa_Inner_3000_5000_10/nuSVR_CountsRMSE_Random_random_rep3_seed9_20_400.txt
#   Sample: random_rep3_seed13_20_400
#     → Best RMSE: 0.354605
#     → Best C:  0.5
#     → Best nu: 0.1
#     → Saved: CIBERSORTx-Matrix_TSP-BDa_Inner_3000_5000_10/nuSVR_CountsRMSE_Random_random_rep3_seed13_20_400.txt
#
# Processing directory: CIBERSORTx-Matrix_TSP-BDa_Inner_300_1500_10/
#   No rerun files found — skipping.
#
# Processing directory: CIBERSORTx-Matrix_TSP-BDa_Outer_1000_3000_10/
#   Sample: random_rep5_seed5_40_800
#     → Best RMSE: 0.429909
#     → Best C:  0.1
#     → Best nu: 0.05
#     → Saved: CIBERSORTx-Matrix_TSP-BDa_Outer_1000_3000_10/nuSVR_CountsRMSE_Random_random_rep5_seed5_40_800.txt
#   Sample: random_rep3_seed11_40_800
#     → Best RMSE: 0.304047
#     → Best C:  0.75
#     → Best nu: 0.75
#     → Saved: CIBERSORTx-Matrix_TSP-BDa_Outer_1000_3000_10/nuSVR_CountsRMSE_Random_random_rep3_seed11_40_800.txt
#   Sample: random_rep4_seed8_40_800
#     → Best RMSE: 0.238234
#     → Best C:  0.5
#     → Best nu: 0.75
#     → Saved: CIBERSORTx-Matrix_TSP-BDa_Outer_1000_3000_10/nuSVR_CountsRMSE_Random_random_rep4_seed8_40_800.txt
#   Sample: random_rep4_seed12_10_200
#     → Best RMSE: 0.459000
#     → Best C:  0.1
#     → Best nu: 0.5
#     → Saved: CIBERSORTx-Matrix_TSP-BDa_Outer_1000_3000_10/nuSVR_CountsRMSE_Random_random_rep4_seed12_10_200.txt
#   Sample: random_rep2_seed12_20_400
#     → Best RMSE: 0.430732
#     → Best C:  1
#     → Best nu: 0.05
#     → Saved: CIBERSORTx-Matrix_TSP-BDa_Outer_1000_3000_10/nuSVR_CountsRMSE_Random_random_rep2_seed12_20_400.txt
#   Sample: random_rep5_seed11_50_1000
#     → Best RMSE: 0.496030
#     → Best C:  0.5
#     → Best nu: 0.5
#     → Saved: CIBERSORTx-Matrix_TSP-BDa_Outer_1000_3000_10/nuSVR_CountsRMSE_Random_random_rep5_seed11_50_1000.txt
#   Sample: random_rep2_seed9_10_200
#     → Best RMSE: 0.400799
#     → Best C:  0.1
#     → Best nu: 0.05
#     → Saved: CIBERSORTx-Matrix_TSP-BDa_Outer_1000_3000_10/nuSVR_CountsRMSE_Random_random_rep2_seed9_10_200.txt
#   Sample: random_rep2_seed12_10_200
#     → Best RMSE: 0.658635
#     → Best C:  0.1
#     → Best nu: 0.1
#     → Saved: CIBERSORTx-Matrix_TSP-BDa_Outer_1000_3000_10/nuSVR_CountsRMSE_Random_random_rep2_seed12_10_200.txt
#   Sample: random_rep3_seed11_30_600
#     → Best RMSE: 0.533259
#     → Best C:  0.1
#     → Best nu: 0.05
#     → Saved: CIBERSORTx-Matrix_TSP-BDa_Outer_1000_3000_10/nuSVR_CountsRMSE_Random_random_rep3_seed11_30_600.txt
#   Sample: random_rep2_seed3_10_200
#     → Best RMSE: 0.408712
#     → Best C:  0.5
#     → Best nu: 0.75
#     → Saved: CIBERSORTx-Matrix_TSP-BDa_Outer_1000_3000_10/nuSVR_CountsRMSE_Random_random_rep2_seed3_10_200.txt
#   Sample: random_rep5_seed11_10_200
#     → Best RMSE: 0.437349
#     → Best C:  0.5
#     → Best nu: 0.25
#     → Saved: CIBERSORTx-Matrix_TSP-BDa_Outer_1000_3000_10/nuSVR_CountsRMSE_Random_random_rep5_seed11_10_200.txt
#   Sample: random_rep1_seed13_10_200
#     → Best RMSE: 0.461897
#     → Best C:  10
#     → Best nu: 0.05
#     → Saved: CIBERSORTx-Matrix_TSP-BDa_Outer_1000_3000_10/nuSVR_CountsRMSE_Random_random_rep1_seed13_10_200.txt
#   Sample: random_rep3_seed3_20_400
#     → Best RMSE: 0.277430
#     → Best C:  0.1
#     → Best nu: 0.75
#     → Saved: CIBERSORTx-Matrix_TSP-BDa_Outer_1000_3000_10/nuSVR_CountsRMSE_Random_random_rep3_seed3_20_400.txt
#   Sample: random_rep5_seed8_20_400
#     → Best RMSE: 0.446227
#     → Best C:  0.1
#     → Best nu: 0.5
#     → Saved: CIBERSORTx-Matrix_TSP-BDa_Outer_1000_3000_10/nuSVR_CountsRMSE_Random_random_rep5_seed8_20_400.txt
#
# Processing directory: CIBERSORTx-Matrix_TSP-BDa_Outer_3000_5000_10/
#   Sample: random_rep3_seed3_10_200
#     → Best RMSE: 0.421475
#     → Best C:  0.5
#     → Best nu: 0.5
#     → Saved: CIBERSORTx-Matrix_TSP-BDa_Outer_3000_5000_10/nuSVR_CountsRMSE_Random_random_rep3_seed3_10_200.txt
#   Sample: random_rep4_seed9_20_400
#     → Best RMSE: 0.236203
#     → Best C:  0.5
#     → Best nu: 0.75
#     → Saved: CIBERSORTx-Matrix_TSP-BDa_Outer_3000_5000_10/nuSVR_CountsRMSE_Random_random_rep4_seed9_20_400.txt
#   Sample: random_rep2_seed13_20_400
#     → Best RMSE: 0.319296
#     → Best C:  0.5
#     → Best nu: 0.5
#     → Saved: CIBERSORTx-Matrix_TSP-BDa_Outer_3000_5000_10/nuSVR_CountsRMSE_Random_random_rep2_seed13_20_400.txt
#   Sample: random_rep3_seed7_40_800
#     → Best RMSE: 0.363333
#     → Best C:  10
#     → Best nu: 0.75
#     → Saved: CIBERSORTx-Matrix_TSP-BDa_Outer_3000_5000_10/nuSVR_CountsRMSE_Random_random_rep3_seed7_40_800.txt
#   Sample: random_rep4_seed7_20_400
#     → Best RMSE: 0.475211
#     → Best C:  0.1
#     → Best nu: 0.75
#     → Saved: CIBERSORTx-Matrix_TSP-BDa_Outer_3000_5000_10/nuSVR_CountsRMSE_Random_random_rep4_seed7_20_400.txt
#   Sample: random_rep4_seed9_10_200
#     → Best RMSE: 0.443379
#     → Best C:  0.1
#     → Best nu: 0.75
#     → Saved: CIBERSORTx-Matrix_TSP-BDa_Outer_3000_5000_10/nuSVR_CountsRMSE_Random_random_rep4_seed9_10_200.txt
#   Sample: random_rep3_seed13_30_600
#     → Best RMSE: 0.466380
#     → Best C:  10
#     → Best nu: 0.1
#     → Saved: CIBERSORTx-Matrix_TSP-BDa_Outer_3000_5000_10/nuSVR_CountsRMSE_Random_random_rep3_seed13_30_600.txt
#   Sample: random_rep5_seed4_30_600
#     → Best RMSE: 0.234077
#     → Best C:  10
#     → Best nu: 0.15
#     → Saved: CIBERSORTx-Matrix_TSP-BDa_Outer_3000_5000_10/nuSVR_CountsRMSE_Random_random_rep5_seed4_30_600.txt
#   Sample: random_rep3_seed4_20_400
#     → Best RMSE: 0.415393
#     → Best C:  10
#     → Best nu: 0.05
#     → Saved: CIBERSORTx-Matrix_TSP-BDa_Outer_3000_5000_10/nuSVR_CountsRMSE_Random_random_rep3_seed4_20_400.txt
#
# Processing directory: CIBERSORTx-Matrix_TSP-BDa_Outer_300_1500_10/
#   Sample: random_rep1_seed11_10_200
#     → Best RMSE: 0.427041
#     → Best C:  0.75
#     → Best nu: 0.5
#     → Saved: CIBERSORTx-Matrix_TSP-BDa_Outer_300_1500_10/nuSVR_CountsRMSE_Random_random_rep1_seed11_10_200.txt
#   Sample: random_rep3_seed5_40_800
#     → Best RMSE: 0.499769
#     → Best C:  10
#     → Best nu: 0.1
#     → Saved: CIBERSORTx-Matrix_TSP-BDa_Outer_300_1500_10/nuSVR_CountsRMSE_Random_random_rep3_seed5_40_800.txt
#   Sample: random_rep3_seed8_10_200
#     → Best RMSE: 0.366541
#     → Best C:  10
#     → Best nu: 0.1
#     → Saved: CIBERSORTx-Matrix_TSP-BDa_Outer_300_1500_10/nuSVR_CountsRMSE_Random_random_rep3_seed8_10_200.txt
#   Sample: random_rep4_seed10_10_200
#     → Best RMSE: 0.285780
#     → Best C:  0.1
#     → Best nu: 0.75
#     → Saved: CIBERSORTx-Matrix_TSP-BDa_Outer_300_1500_10/nuSVR_CountsRMSE_Random_random_rep4_seed10_10_200.txt
#   Sample: random_rep5_seed12_40_800
#     → Best RMSE: 0.421061
#     → Best C:  1
#     → Best nu: 0.1
#     → Saved: CIBERSORTx-Matrix_TSP-BDa_Outer_300_1500_10/nuSVR_CountsRMSE_Random_random_rep5_seed12_40_800.txt
#   Sample: random_rep4_seed11_20_400
#     → Best RMSE: 0.398639
#     → Best C:  10
#     → Best nu: 0.05
#     → Saved: CIBERSORTx-Matrix_TSP-BDa_Outer_300_1500_10/nuSVR_CountsRMSE_Random_random_rep4_seed11_20_400.txt
#   Sample: random_rep4_seed6_20_400
#     → Best RMSE: 0.556796
#     → Best C:  0.5
#     → Best nu: 0.75
#     → Saved: CIBERSORTx-Matrix_TSP-BDa_Outer_300_1500_10/nuSVR_CountsRMSE_Random_random_rep4_seed6_20_400.txt
#
# Processing directory: CIBERSORTx-Matrix_TSP-HBA_Inner_1000_3000_10/
#   Sample: random_rep4_seed11_40_800
#     → Best RMSE: 0.322960
#     → Best C:  10
#     → Best nu: 0.5
#     → Saved: CIBERSORTx-Matrix_TSP-HBA_Inner_1000_3000_10/nuSVR_CountsRMSE_Random_random_rep4_seed11_40_800.txt
#   Sample: random_rep3_seed11_40_800
#     → Best RMSE: 0.304827
#     → Best C:  0.1
#     → Best nu: 0.75
#     → Saved: CIBERSORTx-Matrix_TSP-HBA_Inner_1000_3000_10/nuSVR_CountsRMSE_Random_random_rep3_seed11_40_800.txt
#   Sample: random_rep3_seed5_50_1000
#     → Best RMSE: 0.367365
#     → Best C:  10
#     → Best nu: 0.75
#     → Saved: CIBERSORTx-Matrix_TSP-HBA_Inner_1000_3000_10/nuSVR_CountsRMSE_Random_random_rep3_seed5_50_1000.txt
#   Sample: random_rep5_seed4_40_800
#     → Best RMSE: 0.387076
#     → Best C:  10
#     → Best nu: 0.1
#     → Saved: CIBERSORTx-Matrix_TSP-HBA_Inner_1000_3000_10/nuSVR_CountsRMSE_Random_random_rep5_seed4_40_800.txt
#   Sample: random_rep5_seed6_10_200
#     → Best RMSE: 0.409357
#     → Best C:  0.75
#     → Best nu: 0.05
#     → Saved: CIBERSORTx-Matrix_TSP-HBA_Inner_1000_3000_10/nuSVR_CountsRMSE_Random_random_rep5_seed6_10_200.txt
#   Sample: random_rep3_seed7_10_200
#     → Best RMSE: 0.605979
#     → Best C:  10
#     → Best nu: 0.25
#     → Saved: CIBERSORTx-Matrix_TSP-HBA_Inner_1000_3000_10/nuSVR_CountsRMSE_Random_random_rep3_seed7_10_200.txt
#   Sample: random_rep3_seed9_10_200
#     → Best RMSE: 0.293345
#     → Best C:  0.5
#     → Best nu: 0.5
#     → Saved: CIBERSORTx-Matrix_TSP-HBA_Inner_1000_3000_10/nuSVR_CountsRMSE_Random_random_rep3_seed9_10_200.txt
#
# Processing directory: CIBERSORTx-Matrix_TSP-HBA_Inner_3000_5000_10/
#   Sample: random_rep5_seed6_50_1000
#     → Best RMSE: 0.283508
#     → Best C:  1
#     → Best nu: 0.75
#     → Saved: CIBERSORTx-Matrix_TSP-HBA_Inner_3000_5000_10/nuSVR_CountsRMSE_Random_random_rep5_seed6_50_1000.txt
#   Sample: random_rep2_seed13_10_200
#     → Best RMSE: 0.450708
#     → Best C:  1
#     → Best nu: 0.75
#     → Saved: CIBERSORTx-Matrix_TSP-HBA_Inner_3000_5000_10/nuSVR_CountsRMSE_Random_random_rep2_seed13_10_200.txt
#   Sample: random_rep2_seed11_30_600
#     → Best RMSE: 0.470065
#     → Best C:  0.5
#     → Best nu: 0.5
#     → Saved: CIBERSORTx-Matrix_TSP-HBA_Inner_3000_5000_10/nuSVR_CountsRMSE_Random_random_rep2_seed11_30_600.txt
#   Sample: random_rep2_seed5_50_1000
#     → Best RMSE: 0.448556
#     → Best C:  0.5
#     → Best nu: 0.75
#     → Saved: CIBERSORTx-Matrix_TSP-HBA_Inner_3000_5000_10/nuSVR_CountsRMSE_Random_random_rep2_seed5_50_1000.txt
#   Sample: random_rep4_seed7_30_600
#     → Best RMSE: 0.335070
#     → Best C:  0.1
#     → Best nu: 0.5
#     → Saved: CIBERSORTx-Matrix_TSP-HBA_Inner_3000_5000_10/nuSVR_CountsRMSE_Random_random_rep4_seed7_30_600.txt
#   Sample: random_rep1_seed10_10_200
#     → Best RMSE: 0.371113
#     → Best C:  0.1
#     → Best nu: 0.75
#     → Saved: CIBERSORTx-Matrix_TSP-HBA_Inner_3000_5000_10/nuSVR_CountsRMSE_Random_random_rep1_seed10_10_200.txt
#   Sample: random_rep5_seed3_10_200
#     → Best RMSE: 0.406804
#     → Best C:  0.1
#     → Best nu: 0.5
#     → Saved: CIBERSORTx-Matrix_TSP-HBA_Inner_3000_5000_10/nuSVR_CountsRMSE_Random_random_rep5_seed3_10_200.txt
#   Sample: random_rep1_seed6_40_800
#     → Best RMSE: 0.430634
#     → Best C:  0.5
#     → Best nu: 0.5
#     → Saved: CIBERSORTx-Matrix_TSP-HBA_Inner_3000_5000_10/nuSVR_CountsRMSE_Random_random_rep1_seed6_40_800.txt
#   Sample: random_rep4_seed9_10_200
#     → Best RMSE: 0.457599
#     → Best C:  0.1
#     → Best nu: 0.5
#     → Saved: CIBERSORTx-Matrix_TSP-HBA_Inner_3000_5000_10/nuSVR_CountsRMSE_Random_random_rep4_seed9_10_200.txt
#
# Processing directory: CIBERSORTx-Matrix_TSP-HBA_Inner_300_1500_10/
#   Sample: random_rep3_seed13_40_800
#     → Best RMSE: 0.200409
#     → Best C:  0.1
#     → Best nu: 0.75
#     → Saved: CIBERSORTx-Matrix_TSP-HBA_Inner_300_1500_10/nuSVR_CountsRMSE_Random_random_rep3_seed13_40_800.txt
